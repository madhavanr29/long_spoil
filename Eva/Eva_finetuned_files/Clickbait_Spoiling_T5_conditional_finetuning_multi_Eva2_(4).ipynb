# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')
import json

# %%
import io
# import pandas as pd
# from google.colab import files
from collections import OrderedDict
import inspect as inspector
import sys
import argparse
# import json
import time
import random
import hashlib

# %%
# !pip install -q "tensorflow-text"

import requests
import tensorflow as tf
import tensorflow_text as tf_text
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 92.5 MB/s eta 0:00:00

# %%
# !pip install tqdm boto3 requests regex sentencepiece sacremoses

# !pip install transformers #==2.9.0
# !pip install torch  #==2.0.0

# !pip install https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.1.0-py3-none-any.whl

# !pip install accelerate
# !pip install transformers==2.9.0 
# !pip install pytorch_lightning  #==0.7.5
# !pip install datsets transformers[sentencepiece]
# !pip install sentencepiece

# !pip install Sentencepiece
# !pip install transformers

# !pip install accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Collecting boto3
#   Downloading boto3-1.26.133-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (2022.10.31)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.1 MB/s eta 0:00:00
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 60.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting botocore<1.30.0,>=1.29.133 (from boto3)
#   Downloading botocore-1.29.133-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 103.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.30.0,>=1.29.133->boto3) (2.8.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=2c8df4ab276fb46ca16d6cab085c0797e08b215bf01d30c1d2fe6ec045518916
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# Installing collected packages: sentencepiece, sacremoses, jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.26.133 botocore-1.29.133 jmespath-1.0.1 s3transfer-0.6.1 sacremoses-0.0.53 sentencepiece-0.1.99
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.19.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.0.2-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.22.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.0.0+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.4.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 47.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.27.1)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (16.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.9 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch_lightning) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch_lightning) (1.3.0)
# Installing collected packages: multidict, lightning-utilities, frozenlist, async-timeout, yarl, aiosignal, aiohttp, torchmetrics, pytorch_lightning
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 lightning-utilities-0.8.0 multidict-6.0.4 pytorch_lightning-2.0.2 torchmetrics-0.11.4 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.19.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->accelerate) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate) (1.3.0)

# %%
data_path = './train.jsonl'
df = pd.read_json(data_path, lines=True)
df_validation = pd.read_json('./validation.jsonl', lines=True)

# %%
def concatenate_strings(lst):
    separator = ' '
    return separator.join(lst)

# %%
df['targetParagraphs'] = df['targetParagraphs'].apply(concatenate_strings)
df['postText'] = df['postText'].apply(concatenate_strings)
df['spoiler'] = df['spoiler'].apply(concatenate_strings)
df['tags'] = df['tags'].apply(concatenate_strings)

# %%
df_validation['targetParagraphs'] = df_validation['targetParagraphs'].apply(concatenate_strings)
df_validation['postText'] = df_validation['postText'].apply(concatenate_strings)
df_validation['spoiler'] = df_validation['spoiler'].apply(concatenate_strings)
df_validation['tags'] = df_validation['tags'].apply(concatenate_strings)

# %%
filter_phrase = df['tags'] == "multi"
df_filtered = df[filter_phrase]
# print (df_filtered)

# %%
filter_phrase_validation = df_validation['tags'] == "multi"
df_filtered_validation = df_validation[filter_phrase_validation]
# print (df_filtered_validation)

# %%
def generate_new_df(df):

    new_df = pd.DataFrame({'tags': df['tags'],'postText':df['postText'],'paragraph' : df['targetParagraphs'] ,'spoiler': df['spoiler']})
    return new_df

# %%
# nltk
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# plotting
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.pyplot as plt



# sklearn

from sklearn.metrics import confusion_matrix, classification_report

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer



# Utility

import re
import string
import pickle

# %%
wordLemm = WordNetLemmatizer()
def processed_postText(paragraph):
    # Lower Casing
    paragraph = paragraph.lower()
    # Remove punctuations
    paragraph = paragraph.translate(str.maketrans("","",string.punctuation))
    # Tokenizing words
    tokens = word_tokenize(paragraph)
    # Removing Stop Words
    #final_tokens = [w for w in tokens if w not in stopword]
    # Reducing a word to its word stem using lemmatization
    
    return ' '.join(tokens)

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('stopwords')
stopword = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
new_df = generate_new_df(df_filtered)

# %%
new_df_validation = generate_new_df(df_filtered_validation)

# %%
 new_df['paragraph'] = new_df['paragraph'].apply(lambda x: processed_postText(x))
 new_df['postText'] = new_df['postText'].apply(lambda x: processed_postText(x))
# print('Text Preprocessing complete.')

# %%
 new_df_validation['paragraph'] = new_df_validation['paragraph'].apply(lambda x: processed_postText(x))
 new_df_validation['postText'] = new_df_validation['postText'].apply(lambda x: processed_postText(x))

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
# questions= new_df['postText']
# answers= new_df['spoiler']
# stories_not_summarized = new_df['paragraph']
# tags = new_df['tags']

# print(stories_not_summarized[0])

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb
#   Downloading wandb-0.15.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.22.2-py2.py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 22.2 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=4ad696823ea22a72e84ccbfb1a2755f784450c80282455caa09debe79652008b
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.22.2 setproctitle-1.3.2 smmap-5.0.0 wandb-0.15.2

# %%
import torch

# %%
# from transformers import pipeline
# import requests
# import pprint
# import time
# pp = pprint.PrettyPrinter(indent=14)

# from transformers import T5Tokenizer, T5ForConditionalGeneration
# import wandb

# tokenizer = T5Tokenizer.from_pretrained("t5-small")
# model = T5ForConditionalGeneration.from_pretrained('t5-small')


# # model = T5ForConditionalGeneration.from_pretrained('t5-small')
# # tokenizer = T5Tokenizer.from_pretrained('t5-small')
# device_cuda = torch.device('cuda')
# Out:
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
WANDB_INTEGRATION = True
if WANDB_INTEGRATION:
    import wandb

    wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from datetime import datetime

# %%
if WANDB_INTEGRATION:
    wandb_run = wandb.init(
        project="bart_wiki_lingua",
        config={
            "per_device_train_batch_size": 4
            # "learning_rate": training_args.learning_rate
            # "dataset": "wiki_lingua " + "english",
        },
    )

    now = datetime.now()
    current_time = now.strftime("%H%M%S")
    wandb_run.name = "run_" + "english" + "_" + current_time
# Out:
# wandb: Currently logged in as: pradhaneva94 (evapradhan). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/content/wandb/run-20230512_064058-jt0bv7m0</code>
# Syncing run <strong><a href='https://wandb.ai/evapradhan/bart_wiki_lingua/runs/jt0bv7m0' target="_blank">daily-durian-46</a></strong> to <a href='https://wandb.ai/evapradhan/bart_wiki_lingua' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/evapradhan/bart_wiki_lingua' target="_blank">https://wandb.ai/evapradhan/bart_wiki_lingua</a>
#  View run at <a href='https://wandb.ai/evapradhan/bart_wiki_lingua/runs/jt0bv7m0' target="_blank">https://wandb.ai/evapradhan/bart_wiki_lingua/runs/jt0bv7m0</a>

# %%
# # summarize with T5
# # summarizer_t5 = pipeline(task='summarization', model="t5-large")
# summarizer_t5 = pipeline(task='summarization', model="t5-small")

# %%
#FINE TUNING START

# %%
# !pip install transformers #==2.9.0
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 24.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, responses, multiprocess, datasets
# Successfully installed datasets-2.12.0 dill-0.3.6 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0

# %%
from datasets import Dataset
from datasets import dataset_dict

# %%
import transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset, load_from_disk
import numpy as np
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import torch
import numpy as np
import pandas as pd
from transformers import (TrainingArguments, Trainer, EarlyStoppingCallback)
from sklearn.metrics import accuracy_score, f1_score
from datasets import Dataset, load_metric
from transformers import AutoTokenizer, T5ForConditionalGeneration

# %%
# max_input = 512
# max_target = 128
# batch_size = 3
model_checkpoints = "t5-small"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoints)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %%
input_text = "Sumarize:" + "condition: " + new_df['postText'] + " paragraph: " + new_df["paragraph"]
target_text = new_df["spoiler"]


data_to_process_train = pd.DataFrame({ 'input_ids': input_text, 'labels':target_text})

# %%
data_to_process_train
# Out:
#                                               input_ids  \
# 3     Sumarize:condition: passion is overrated — 7 w...
# 9     Sumarize:condition: hot sauce taste test find ...
# 20    Sumarize:condition: human remains found in the...
# 43    Sumarize:condition: six lessons from the godfa...
# 44    Sumarize:condition: the fastest growing econom...
# ...                                                 ...
# 3188  Sumarize:condition: medical marijuana bills ad...
# 3190  Sumarize:condition: this guy cheated on the pr...
# 3191  Sumarize:condition: 7 small changes to try thi...
# 3192  Sumarize:condition: 11 of the weirdest foods y...
# 3197  Sumarize:condition: 5 popular myths about visi...
#
#                                                  labels
# 3     Purpose connects us to something bigger and in...
# 9     Sriracha Hot Chili Sauce Frank's RedHot Origin...
# 20             Southampton County Anjelica 'AJ' Hadsell
# 43    Daniel Patterson 1) Eat your veggies. 2) Enjoy...
# 44    1. India 2. Bangladesh 3. China 4. Indonesia 5...
# ...                                                 ...
# 3188                                   Georgia Kentucky
# 3190  Terry Kniess All of the prices in the show hav...
# 3191  Relax with rain sounds. Put pressure on period...
# 3192  Cream cheese with a bit of strawberry jam on a...
# 3197  1. Anti-wrinkle creams will erase the fine lin...
#
# [559 rows x 2 columns]

# %%
df1_dict = data_to_process_train.to_dict(orient = 'list')

# %%
dict_train_ = Dataset.from_dict(df1_dict)

# %%
dict_train_
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 559
# })

# %%
input_text = "Sumarize:" + "condition: " + new_df_validation['postText'] + " paragraph: " + new_df_validation["paragraph"]
target_text = new_df_validation["spoiler"]

data_to_process_validation = pd.DataFrame({ 'input_ids': input_text, 'labels':target_text})

# %%
data_to_process_train
# Out:
#                                               input_ids  \
# 3     Sumarize:condition: passion is overrated — 7 w...
# 9     Sumarize:condition: hot sauce taste test find ...
# 20    Sumarize:condition: human remains found in the...
# 43    Sumarize:condition: six lessons from the godfa...
# 44    Sumarize:condition: the fastest growing econom...
# ...                                                 ...
# 3188  Sumarize:condition: medical marijuana bills ad...
# 3190  Sumarize:condition: this guy cheated on the pr...
# 3191  Sumarize:condition: 7 small changes to try thi...
# 3192  Sumarize:condition: 11 of the weirdest foods y...
# 3197  Sumarize:condition: 5 popular myths about visi...
#
#                                                  labels
# 3     Purpose connects us to something bigger and in...
# 9     Sriracha Hot Chili Sauce Frank's RedHot Origin...
# 20             Southampton County Anjelica 'AJ' Hadsell
# 43    Daniel Patterson 1) Eat your veggies. 2) Enjoy...
# 44    1. India 2. Bangladesh 3. China 4. Indonesia 5...
# ...                                                 ...
# 3188                                   Georgia Kentucky
# 3190  Terry Kniess All of the prices in the show hav...
# 3191  Relax with rain sounds. Put pressure on period...
# 3192  Cream cheese with a bit of strawberry jam on a...
# 3197  1. Anti-wrinkle creams will erase the fine lin...
#
# [559 rows x 2 columns]

# %%
df2_dict = data_to_process_validation.to_dict(orient = 'list')

# %%
dict_validation_ = Dataset.from_dict(df2_dict)

# %%
dict_validation_
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 143
# })

# %%
input_text = "Sumarize:" + "condition: " + new_df_validation['postText'] + " paragraph: " + new_df_validation["paragraph"]
target_text = new_df_validation["spoiler"]

data_to_process_test = pd.DataFrame({ 'input_ids': input_text, 'labels':target_text})

# %%
data_to_process_test
# Out:
#                                              input_ids  \
# 1    Sumarize:condition: why arizona sheriff joe ar...
# 3    Sumarize:condition: harry potter alums reunite...
# 10   Sumarize:condition: how 1 model prepares for l...
# 13   Sumarize:condition: the question former oj sim...
# 14   Sumarize:condition: hollywood legends amazing ...
# ..                                                 ...
# 785  Sumarize:condition: 6 transcendental festivals...
# 788  Sumarize:condition: things in the olsen twins ...
# 789  Sumarize:condition: 13 pokémon the designers j...
# 790  Sumarize:condition: 9 things elizabeth taylor ...
# 797  Sumarize:condition: this beauty queen cured he...
#
#                                                 labels
# 1    "intentionally" could transform a court case a...
# 3                     Alan Rickman & Rupert Grint CBGB
# 10   Elettra Wiedemann extra strength work, so weig...
# 13   Marcia Clark Does she think Simpson really did...
# 14              Mitzi Gaynor Beverly Hills, California
# ..                                                 ...
# 785  BOOM – Portugal Meadows in the Mountains – Bul...
# 788  earned much of their fortune making unintentio...
# 789     Klefki Rotom Luvdisk Unknown (Unown) Vanilluxe
# 790  I don’t pretend to be an ordinary housewife Pe...
# 797  Rachel Crawley High fat vegan plant based diet...
#
# [143 rows x 2 columns]

# %%
df3_dict = data_to_process_test.to_dict(orient = 'list')

# %%
dict_test_ = Dataset.from_dict(df3_dict)

# %%
dict_test_
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 143
# })

# %%
# df1_dict = data_to_process_train.to_dict(orient = 'list')
# df2_dict = data_to_process_validation.to_dict(orient = 'list')
# df3_dict = data_to_process_test.to_dict(orient = 'list')


# dict_train_ = Dataset.from_dict(df1_dict)
# dict_validation_ = Dataset.from_dict(df2_dict)
# dict_test_ = Dataset.from_dict(df3_dict)

# %%
dict_all_2 = dataset_dict.DatasetDict({"train":dict_train_, "validation":dict_validation_, "test": dict_test_})

# %%
dict_all_2
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 559
#     })
#     validation: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 143
#     })
#     test: Dataset({
#         features: ['input_ids', 'labels'],
#         num_rows: 143
#     })
# })

# %%
dict_train_
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 559
# })

# %%
model = "t5-small"

# %%
tokenizer1 = tokenizer.from_pretrained("t5-small")

# %%
def preprocess_data(example):
    input_text = example['input_ids']
    target_text = example['labels']

    input_ids = tokenizer1(input_text, padding="max_length", truncation=True, max_length= 1000).input_ids

    with tokenizer1.as_target_tokenizer():
      target_ids = tokenizer1(target_text, padding='max_length', truncation=True, max_length= 500).input_ids
    # target_ids = tokenizer(target_text, padding="max_length", truncation=True, max_length= 500, return_tensors="pt").input_ids
    
    return {"input_ids": input_ids, "labels": target_ids}
    # return {"input_text": input_text, "target_text": target_text}

# %%
train_dataset = dict_train_
test_dataset = dict_validation_

train_dataset_processed = train_dataset.map(preprocess_data)
test_dataset_processed = test_dataset.map(preprocess_data)
# Out:
# Map:   0%|          | 0/559 [00:00<?, ? examples/s]
# Map:   0%|          | 0/143 [00:00<?, ? examples/s]

# %%
train_dataset_processed
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 559
# })

# %%
test_dataset_processed
# Out:
# Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 143
# })

# %%
from transformers import pipeline
import requests
import pprint
import time
pp = pprint.PrettyPrinter(indent=14)

from transformers import T5Tokenizer, T5ForConditionalGeneration
# import wandb

# tokenizer = T5Tokenizer.from_pretrained("t5-small")
# model = T5ForConditionalGeneration.from_pretrained('t5-small')

# %%
model_name = "t5-small"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name, num_labels = 4)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# !pip install bert_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.0.0+cu118)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.5.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.29.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.27.1)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score) (16.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.14.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=3.0.0->bert_score) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
bleu_metric = load_metric("bleu")
meteor_metric = load_metric("meteor")
bertscore_metric = load_metric("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/2.48k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Downloading builder script:   0%|          | 0.00/2.92k [00:00<?, ?B/s]

# %%
#out_1 = []
#out_2 = []

def compute_metrics(eval_pred):
    logits_full, labels = eval_pred

    #out_1.append(logits_full[0])
    #out_2.append(logits_full[1])

    predicted_token_ids = torch.argmax(torch.tensor(logits_full[0]), dim=-1).tolist()
    decoded_preds = tokenizer.batch_decode(predicted_token_ids, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds_bleu = [pred.split() for pred in decoded_preds]
    decoded_labels_bleu = [[pred.split()] for pred in decoded_labels]
    
    bleu_score = bleu_metric.compute(predictions=decoded_preds_bleu, references= decoded_labels_bleu)
    meteor_score = meteor_metric.compute(predictions=decoded_preds, references=decoded_labels)
    bertscore_score = bertscore_metric.compute(predictions=decoded_preds, references=decoded_labels, lang = 'en')
    
    return {"bleu": bleu_score["bleu"], "meteor": meteor_score["meteor"], "bertscore": np.mean(bertscore_score["f1"])}

# %%
import shutil

# %%
training_args = TrainingArguments(
    output_dir=f"/content/drive/MyDrive/T5_finetuning_results_multi_conditional_all_sizelimited",
    num_train_epochs=24,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    # gradient_accumulation_steps=2,
    evaluation_strategy="epoch",
    logging_steps=100,
    learning_rate=2e-5,
    weight_decay=0.01,
    save_total_limit=3,
    # predict_with_generate=True,
    fp16=True,
    # save_strategy="epoch"

)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset_processed,
    eval_dataset=test_dataset_processed,
    tokenizer=tokenizer,
    # data_collator=data_collator,
    # compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3360' max='3360' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3360/3360 20:41, Epoch 24/24]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.635000</td>
#       <td>0.379566</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.408500</td>
#       <td>0.291683</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.268200</td>
#       <td>0.263560</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.237100</td>
#       <td>0.249060</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.221800</td>
#       <td>0.237984</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.219100</td>
#       <td>0.230885</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.209100</td>
#       <td>0.220600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.193600</td>
#       <td>0.216856</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.198500</td>
#       <td>0.211130</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.181200</td>
#       <td>0.206265</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.171200</td>
#       <td>0.201631</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.195000</td>
#       <td>0.198586</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.173800</td>
#       <td>0.197608</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.174900</td>
#       <td>0.195847</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.170600</td>
#       <td>0.192503</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.163700</td>
#       <td>0.191412</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.168700</td>
#       <td>0.190421</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.161000</td>
#       <td>0.188961</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.166200</td>
#       <td>0.187986</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.163000</td>
#       <td>0.186975</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.162200</td>
#       <td>0.186467</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.166800</td>
#       <td>0.186161</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.165100</td>
#       <td>0.185813</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.160300</td>
#       <td>0.185875</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3360, training_loss=0.2675135183902014, metrics={'train_runtime': 1245.3932, 'train_samples_per_second': 10.773, 'train_steps_per_second': 2.698, 'total_flos': 3546378141696000.0, 'train_loss': 0.2675135183902014, 'epoch': 24.0})

# %%
metrics = trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='36' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36/36 00:04]
#     </div>

# %%
metrics
# Out:
# {'eval_loss': 0.18587525188922882,
#  'eval_runtime': 4.2973,
#  'eval_samples_per_second': 33.276,
#  'eval_steps_per_second': 8.377,
#  'epoch': 24.0}

# %%
dict_validation_["labels"]

# %%
def generate_summary(test_samples, model):
    inputs = tokenizer(
        test_samples["labels"],
        padding="max_length",
        truncation=True,
        max_length=1000,
        return_tensors="pt",
    )
    input_ids = inputs.input_ids.to(model.device)
    attention_mask = inputs.attention_mask.to(model.device)
    outputs = model.generate(input_ids, attention_mask=attention_mask)
    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return outputs, output_str

# %%
# model_before_tuning = AutoModelForSeq2SeqLM.from_pretrained(model_name)
summaries_after_tuning_all = []

def generate_batch(lst, batch_size):
    """  Yields batch of specified size """
    for i in range(0, len(lst), batch_size):
        yield lst[i : i + batch_size]
        # summaries_after_tuning = generate_summary(test_samples, model)[1]
        # summaries_after_tuning_all.append(summaries_after_tuning)


# test_samples = dict_validation_.select(range())
test_samples = generate_batch(dict_validation_, 16)

# # summaries_before_tuning = generate_summary(test_samples, model_before_tuning)[1]

for batch in test_samples:
  # print(batch)
  summaries_after_tuning = generate_summary(batch, model)[1]
  summaries_after_tuning_all.append(summaries_after_tuning)

# %%
summaries_after_tuning_all
# Out:
# [['"intentionally" could transform a court case against Phoenix-area Sheriff Joe Arpai',
#   'Alan Rickman & Rupert Grint CBGB',
#   ', so weights, and quite a few planks for my core. My',
#   'Marcia Clark Does she think Simpson really did it?',
#   'Mitzi Gaynor Beverly Hills, California',
#   'Paige Hathaway – 3,8m £3.8m Chantel Zales –',
#   'cleaner glass scraper is ideal for removing tough stains remove grease build-up on',
#   '. I want painful, difficult, devastating, life-changing, extraordinary love. Don’',
#   'will cause an environmental catastrophe. 4. The chandelier in Elton John’s private jet will',
#   'Vince Carter Paul Pierce Dirk Nowitzki',
#   'Die Baking soda Beee stings.',
#   '         ',
#   'Almario alleged physical abuse and uploading their sexual video online.',
#   '1. Washing Your Face 2. Not Washing Your Feet 3. Not Washing or Replac',
#   'comatose kind of situation, or you’re not really responsive, that',
#   'Yuliana Avalos Match.com’s parent company, IAC (InterActiv'],
#  ['Tromp and their adult children Ella, Riana and Mitchell left their home in Silva',
#   'as a utility farmer, picking up trash at the city dump in 100-plus degree',
#   'Lukas Graham’s hit song "7 Years" sang his very own special rendition of',
#   'Mylan has patent protection that lasts through 2025 2. There’s no room for',
#   ', and I want to enjoy my life, and food is a big part of it',
#   'You buy hemp milk. 2. You buy hemp milk. 2. You buy hemp milk. 2.',
#   '15 Kristen Stewart 14 Aubrey Plaza 13 Mara Wilson 13 Mara Wilson 12 Co',
#   'Chantelle major plastic surgery to repair her injuries',
#   'Savannah Guthrie got married four months pregnant',
#   'Jason Brian Rosenthal',
#   'Joe McGrath Joe McGrath Joe McGrath Joe McGrath Joe McGrat',
#   '1. "Never-Before-Seen Photos Behind the Scenes at the',
#   'Eltern were involved in political activism of some kind conflict-heavy family life, but that conflict',
#   '         ',
#   'Dahlesque Golden ticket Human bean Oompa Loompa Scrumdiddly',
#   'web (m.reddit.com) is undergoing a major overhaul new'],
#  ['Guinness World Record: the most peanut butter and jelly sandwiches made in an hour 49100',
#   'Daisy Ridley endometriosis Daisy Ridley endometrios',
#   'Starbucks prevents you from losing it on your kids. 2. You definitely have no energy to',
#   'Oil is making a comeback An early Twitter investor hates the stock An early Twitter investor',
#   ', should be replaced every six months eyeliner and mascara, should be replaced every three',
#   '         ',
#   'Sultan Moulay Ismal of Morocco have sex an average of 0.',
#   'Drug Policy Alliance 4. Charlo Greene,Founder of Alaska Cannabis Club 5. Jessica Peter',
#   'Abraj Kudai Mecca, Saudi Arabia',
#   'Holt is a registered Republican Holt is the first black presidential debate moderator since',
#   'InFlow Carta Rightcontrol Lite Odoo ABC Inventory',
#   'Invest wisely: Don’t invest in anything unless you are prepared to put at',
#   'Cleopatra lived closer in time to the invention of Snapchat than to the',
#   "'hooking up with strangers' treats her 'like a sex",
#   '1. Cold-Weather Clothing 2. Back-to-School Supplies 3. Theme Park Tickets',
#   "Hayley Greenberg Jingee's previous owners had taught him how to use the"],
#  ['. 4. Find something you love about yourself and show it off. 4. Find something you love',
#   'Jessica Jessica 2. Jessica 2. Jessica 2. Amy 3. Jade 4. Rebecca 5. Charlotte',
#   'stocks are at all-time highs. The ECB meets on Thursday. China',
#   'Andy Mizrahi, a',
#   '. Make Work Easier for Mothers Build More Flexible Workplaces Change the',
#   'Derrick Taylor er wurde vorgestellt.',
#   '1. Emphasize productivity. 2. Emphasize productivity. 2. Evaluate potential ROI. 3.',
#   'Sarah Brown sa Sarah Brown ne sah Sarah Brown sa',
#   'Umbridge was arrested, interrogated and imprisoned for crimes against Mugg',
#   's Angle Grinders Russian Men with Chairs Russian Men with Chairs with Chairs',
#   'The big pause The eye dart The lost breath Overcompensating The poker face',
#   'Mike Tyson 5) Loretta Lynn 4) Joe Arpaio 3) Wayne Newton A',
#   'Aamir Khan Aims To Make Maharashtra Drought Free In The',
#   'Die National Vietnam Veterans Foundation hat weniger als 2 Prozent für die tatsächlichen Veteranen und Veteran',
#   'Markwayne Mullin welcomed two twin girls into his home',
#   'Al Jubail, Saudi Arabia 4. Riyadh, Saudi Arabia 3. Allaha'],
#  ['national catastrophe. a recession. A terrorist attack. A terrorist attack. A divided Democratic',
#   'Eine Studie von Wissenschaftlern von Copenhagen University Hospital, die die Spermazahl eine',
#   'China - opportunity or risk? Russian disruption?',
#   'every other day, but you will not go out with dirty hair. 4. You cannot go',
#   'Plum Creek Timber Rick Holley',
#   "Hala Kamil, the Oscar-nominated dir., wants to make Syria'",
#   'Kathryn Smith Two inmates took justice into their own hands and brutally attacked the',
#   'The statue, titled "Sleepwalker" Wellesley College',
#   's. There will be fights. There will be anger. There will be score-',
#   'Viele U.S.-U.-U.-U.-U.-U',
#   'médiation gardens prayer rooms chapels prayer rooms chapels chapels prayer rooms chapels prayer',
#   'OUT OF SEASON STOCKPILE WHEN THE PRICE IS ',
#   "'s economy grew by 4,1 percent in 2015, according to new numbers from the",
#   '. Double-checking that the high-quality option is checked browser could be causing',
#   'Melissa McCarthy is Abby Yates, Kristen Wiig is Erin Gilbert, Kate',
#   'Virtual Reality will get more physical VR is a industry-wide effort A wireless Rift'],
#  ['"Mandela: Long Walk to Freedom" in 2017',
#   'Die Wirkung des jetlags erhöhte die Luftdruck innerhalb der Kab',
#   'Selbst-crucifixion: Philippines Bunny killing: New Zealand Clay pot throwing:',
#   'are government employees. "Take the mortgage deduction," says a middle-income family.',
#   '1. Take a long, warm shower with sweet-smelling essential oils. 2. Create the perfect',
#   '"Malibu," "Malibu," "The Beach Boy," Homesick for Another',
#   '1. Get an education 2. Say hello to risk 3. Take that risk through index funds 4. Put ',
#   'Y Combinator to test a scheme called Universal Basic Income Income Universal Basic Income Universal Basic',
#   'Thea: The Awakening added multiplayer',
#   '1) Readers wanted to read about it 2) Mad Men debuted right after The Sopranos',
#   '1. Eat legumes 2. Eat plant sterols, margarines and spreads 3.',
#   ', and Michael Cox, who were both born with Down syndrome, have known each other',
#   '#1: Goodbye Sapphire? #2: New Home Button, New Limitations',
#   'to Assimilate Dress for the job you want Be humble and willing to learn from',
#   '1. Museum of Modern Art 2. Metropolitan Museum of Art 3. Guggenheim 4. Whitney Museum of',
#   'Tokyo Chicago Chicago London'],
#  ['1. A SINGLE TABLESPOON HAS MORE SUGAR THAN A',
#   'World War II spy drones spy drones spy drones spy drones spy drones',
#   "1. Adventurous Christmas: Chile 2. Premium Christmas: Switzerland 3. Christmas in Santa's home",
#   'X',
#   "n'est pas établi que vice consumption is different from others in the",
#   '(up to $10 value) with the purchase of an adult entree on Sunday at Ruby',
#   'Andy Stern "tectonic shifts" in the labor market that will see more and more',
#   'Christine "Tink" Newman 4 continuous hours of CPR',
#   'club because they were drunk call staff to the room, and then make them wait outside while',
#   '. The unemployment rate in November fell to 4.6 percent, the lowest in nine years.',
#   'was different enough that people realized it was a different reason to go and see it.',
#   '1. Ideas Have Consequences 2. The Road to Serfdom 3. The Clos',
#   'Kiwi Tart Cherries and Tart Cherry Juice Malted Milk and Nighttime Milk',
#   'Katrina Henry Admit it and go get help.',
#   "1. Don't touch her bump 2. Don't ask if she has chosen a",
#   '. 4. When she looks at you, smile and point to her headphones and say, "'],
#  ['1. Half-Life 3. The Last Guardian 3. Final Fantasy XV 4. Kingdom Hearts 3.',
#   'The action’s going to pick back up in Fall of 1984. 2. The action’',
#   "John Slattery 'God's Pocket' John Slattery ",
#   'My ex raised the thing to eye level, looked at me, and pushed the button',
#   "'sky lanterns' In Pennsylvania, beer customers are now able to purchase six",
#   'are called "Venus Holes" and are formed on the lower back of women',
#   'Trim your pubic hair. Make sure your boner is at maximum capacity.',
#   'Don’t Don’t Don’t Don’t Don’t Don’t Don',
#   'THE MYSTERIOUS ORIGINS THE CAMARADERIE THE TRADITION THE',
#   '’s unending stare can be a little bit disconcerting, but don',
#   "Watch Hill, Rhode Island Hamilton Island on Australia's Great Barrier Reef Cuba, southern Italy town",
#   'Louisville, Kentucky Where Opportunity Knox',
#   '. Coimbatore, India 461. Bhubaneswar, India 462.',
#   '1. Ecuador 2. Nicaragua 3. Nicaragua 3. Thailand 4. Belize 5. Panama',
#   ', the Beast is highly educated, his attitude simply accompanying the crown. the new',
#   'Peter Facinelli "Breaking Bad" Obsession Peter Facinelli "'],
#  ['Diagnostic medical sonographer Diagnostic medical sonographer compliance officer Operations research analyst',
#   'CEO Lawyer Media Salesperson Surgeon',
#   'CHILI PEPPERS 2. WHOLE GRAINS AND VEGABLES 3. BLACK',
#   'Tawny Nelson, the older man wanted was for me to never give up and keep',
#   'Lunch Boxes All of a sudden, some things started coming out of the wood',
#   'The Jump Sir Bradley Wiggins Jade Jones Kadeena Cox Gareth',
#   "Whitney Thompson Panache Lingerie's new Sculptresse line line, Sculpt",
#   'Coconut oil pinch of turmeric',
#   'playing. 2 human players and 2 CPUs resulted in no lag. gets',
#   '1. When it comes to food, you won’t just eat any old thing.',
#   '– Portugal Meadows in the Mountains – Bulgaria Burning Man - Black Rock Desert',
#   'Elizabeth is outgoing, vivacious, and comes off like an extremely well-ad',
#   'Klefki Rotom Luvdisk Unknown (Unown) Vanillux',
#   'I don’t pretend to be an ordinary housewife People always assume you’re going to',
#   'Rachel Crawley High fat vegan plant-based diet (no processed) Real whole foods']]

# %%
# Out:
# 'Einige der plot elements are so disturbing that they make him feel sick.'

# %%
stories_list =[]
for i in range(len(summaries_after_tuning_all)):
  for j in range(len(summaries_after_tuning_all[i])):
    summary=summaries_after_tuning_all[i][j]
    stories_list.append(summary)


print(stories_list)
# Out:
# ['"intentionally" could transform a court case against Phoenix-area Sheriff Joe Arpai', 'Alan Rickman & Rupert Grint CBGB', ', so weights, and quite a few planks for my core. My', 'Marcia Clark Does she think Simpson really did it?', 'Mitzi Gaynor Beverly Hills, California', 'Paige Hathaway – 3,8m £3.8m Chantel Zales –', 'cleaner glass scraper is ideal for removing tough stains remove grease build-up on', '. I want painful, difficult, devastating, life-changing, extraordinary love. Don’', 'will cause an environmental catastrophe. 4. The chandelier in Elton John’s private jet will', 'Vince Carter Paul Pierce Dirk Nowitzki', 'Die Baking soda Beee stings.', '         ', 'Almario alleged physical abuse and uploading their sexual video online.', '1. Washing Your Face 2. Not Washing Your Feet 3. Not Washing or Replac', 'comatose kind of situation, or you’re not really responsive, that', 'Yuliana Avalos Match.com’s parent company, IAC (InterActiv', 'Tromp and their adult children Ella, Riana and Mitchell left their home in Silva', 'as a utility farmer, picking up trash at the city dump in 100-plus degree', 'Lukas Graham’s hit song "7 Years" sang his very own special rendition of', 'Mylan has patent protection that lasts through 2025 2. There’s no room for', ', and I want to enjoy my life, and food is a big part of it', 'You buy hemp milk. 2. You buy hemp milk. 2. You buy hemp milk. 2.', '15 Kristen Stewart 14 Aubrey Plaza 13 Mara Wilson 13 Mara Wilson 12 Co', 'Chantelle major plastic surgery to repair her injuries', 'Savannah Guthrie got married four months pregnant', 'Jason Brian Rosenthal', 'Joe McGrath Joe McGrath Joe McGrath Joe McGrath Joe McGrat', '1. "Never-Before-Seen Photos Behind the Scenes at the', 'Eltern were involved in political activism of some kind conflict-heavy family life, but that conflict', '         ', 'Dahlesque Golden ticket Human bean Oompa Loompa Scrumdiddly', 'web (m.reddit.com) is undergoing a major overhaul new', 'Guinness World Record: the most peanut butter and jelly sandwiches made in an hour 49100', 'Daisy Ridley endometriosis Daisy Ridley endometrios', 'Starbucks prevents you from losing it on your kids. 2. You definitely have no energy to', 'Oil is making a comeback An early Twitter investor hates the stock An early Twitter investor', ', should be replaced every six months eyeliner and mascara, should be replaced every three', '         ', 'Sultan Moulay Ismal of Morocco have sex an average of 0.', 'Drug Policy Alliance 4. Charlo Greene,Founder of Alaska Cannabis Club 5. Jessica Peter', 'Abraj Kudai Mecca, Saudi Arabia', 'Holt is a registered Republican Holt is the first black presidential debate moderator since', 'InFlow Carta Rightcontrol Lite Odoo ABC Inventory', 'Invest wisely: Don’t invest in anything unless you are prepared to put at', 'Cleopatra lived closer in time to the invention of Snapchat than to the', "'hooking up with strangers' treats her 'like a sex", '1. Cold-Weather Clothing 2. Back-to-School Supplies 3. Theme Park Tickets', "Hayley Greenberg Jingee's previous owners had taught him how to use the", '. 4. Find something you love about yourself and show it off. 4. Find something you love', 'Jessica Jessica 2. Jessica 2. Jessica 2. Amy 3. Jade 4. Rebecca 5. Charlotte', 'stocks are at all-time highs. The ECB meets on Thursday. China', 'Andy Mizrahi, a', '. Make Work Easier for Mothers Build More Flexible Workplaces Change the', 'Derrick Taylor er wurde vorgestellt.', '1. Emphasize productivity. 2. Emphasize productivity. 2. Evaluate potential ROI. 3.', 'Sarah Brown sa Sarah Brown ne sah Sarah Brown sa', 'Umbridge was arrested, interrogated and imprisoned for crimes against Mugg', 's Angle Grinders Russian Men with Chairs Russian Men with Chairs with Chairs', 'The big pause The eye dart The lost breath Overcompensating The poker face', 'Mike Tyson 5) Loretta Lynn 4) Joe Arpaio 3) Wayne Newton A', 'Aamir Khan Aims To Make Maharashtra Drought Free In The', 'Die National Vietnam Veterans ...

# %%
# type(new_df['spoiler'][0:40])
# Out:
# pandas.core.series.Series

# %%
type(stories_list[0:40])
# Out:
# list

# %%
stories_list_series = pd.Series((v for v in stories_list))

# %%
import pandas as pd

# %%
new_df_validation['spoiler']
# Out:
# 1      "intentionally" could transform a court case a...
# 3                       Alan Rickman & Rupert Grint CBGB
# 10     Elettra Wiedemann extra strength work, so weig...
# 13     Marcia Clark Does she think Simpson really did...
# 14                Mitzi Gaynor Beverly Hills, California
#                              ...
# 785    BOOM – Portugal Meadows in the Mountains – Bul...
# 788    earned much of their fortune making unintentio...
# 789       Klefki Rotom Luvdisk Unknown (Unown) Vanilluxe
# 790    I don’t pretend to be an ordinary housewife Pe...
# 797    Rachel Crawley High fat vegan plant based diet...
# Name: spoiler, Length: 143, dtype: object

# %%
stories_list

# %%
dataframe = pd.DataFrame({ 'postText': new_df_validation["postText"], 'actual_spoiler':new_df_validation['spoiler'], 'gen_spoiler':stories_list})

# %%
dataframe
# Out:
#                                               postText  \
# 1    why arizona sheriff joe arpaio ’ s fate could ...
# 3             harry potter alums reunite for new movie
# 10            how 1 model prepares for lingerie shoots
# 13   the question former oj simpson prosecutor hate...
# 14     hollywood legends amazing home is on the market
# ..                                                 ...
# 785  6 transcendental festivals out in the middle o...
# 788  things in the olsen twins lives that make no s...
# 789           13 pokémon the designers just gave up on
# 790  9 things elizabeth taylor taught us about the ...
# 797  this beauty queen cured her acne with one diet...
#
#                                         actual_spoiler  \
# 1    "intentionally" could transform a court case a...
# 3                     Alan Rickman & Rupert Grint CBGB
# 10   Elettra Wiedemann extra strength work, so weig...
# 13   Marcia Clark Does she think Simpson really did...
# 14              Mitzi Gaynor Beverly Hills, California
# ..                                                 ...
# 785  BOOM – Portugal Meadows in the Mountains – Bul...
# 788  earned much of their fortune making unintentio...
# 789     Klefki Rotom Luvdisk Unknown (Unown) Vanilluxe
# 790  I don’t pretend to be an ordinary housewife Pe...
# 797  Rachel Crawley High fat vegan plant based diet...
#
#                                            gen_spoiler
# 1    "intentionally" could transform a court case a...
# 3                     Alan Rickman & Rupert Grint CBGB
# 10   , so weights, and quite a few planks for my co...
# 13   Marcia Clark Does she think Simpson really did...
# 14              Mitzi Gaynor Beverly Hills, California
# ..                                                 ...
# 785  – Portugal Meadows in the Mountains – Bulgaria...
# 788  Elizabeth is outgoing, vivacious, and comes of...
# 789      Klefki Rotom Luvdisk Unknown (Unown) Vanillux
# 790  I don’t pretend to be an ordinary housewife Pe...
# 797  Rachel Crawley High fat vegan plant-based diet...
#
# [143 rows x 3 columns]

# %%
file = open("T5_conditional_finetuning_no_tags_multi_results.txt", "w")

#convert variable to string
# str_1 = repr(dataframe)
str2 = dataframe.to_json()
file.write("T5_conditional_finetuning_no_tags_multi_results = " + str2 + "\n")

#close file
file.close()

# %%
if WANDB_INTEGRATION:
    wandb_run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▅▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▁▆▇██████████████████████</td></tr><tr><td>eval/samples_per_second</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/steps_per_second</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/learning_rate</td><td>███▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.18588</td></tr><tr><td>eval/runtime</td><td>4.2973</td></tr><tr><td>eval/samples_per_second</td><td>33.276</td></tr><tr><td>eval/steps_per_second</td><td>8.377</td></tr><tr><td>train/epoch</td><td>24.0</td></tr><tr><td>train/global_step</td><td>3360</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.1603</td></tr><tr><td>train/total_flos</td><td>3546378141696000.0</td></tr><tr><td>train/train_loss</td><td>0.26751</td></tr><tr><td>train/train_runtime</td><td>1245.3932</td></tr><tr><td>train/train_samples_per_second</td><td>10.773</td></tr><tr><td>train/train_steps_per_second</td><td>2.698</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">daily-durian-46</strong> at: <a href='https://wandb.ai/evapradhan/bart_wiki_lingua/runs/jt0bv7m0' target="_blank">https://wandb.ai/evapradhan/bart_wiki_lingua/runs/jt0bv7m0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230512_064058-jt0bv7m0/logs</code>

# %%
#EVALUATION METRICS

# %%
import nltk
import nltk.translate.bleu_score as bleu

import math
import numpy
import os

try:
  nltk.data.find('tokenizers/punkt')
except LookupError:
  nltk.download('punkt')

# %%
dataframe
# Out:
#                                               postText  \
# 1    why arizona sheriff joe arpaio ’ s fate could ...
# 3             harry potter alums reunite for new movie
# 10            how 1 model prepares for lingerie shoots
# 13   the question former oj simpson prosecutor hate...
# 14     hollywood legends amazing home is on the market
# ..                                                 ...
# 785  6 transcendental festivals out in the middle o...
# 788  things in the olsen twins lives that make no s...
# 789           13 pokémon the designers just gave up on
# 790  9 things elizabeth taylor taught us about the ...
# 797  this beauty queen cured her acne with one diet...
#
#                                         actual_spoiler  \
# 1    "intentionally" could transform a court case a...
# 3                     Alan Rickman & Rupert Grint CBGB
# 10   Elettra Wiedemann extra strength work, so weig...
# 13   Marcia Clark Does she think Simpson really did...
# 14              Mitzi Gaynor Beverly Hills, California
# ..                                                 ...
# 785  BOOM – Portugal Meadows in the Mountains – Bul...
# 788  earned much of their fortune making unintentio...
# 789     Klefki Rotom Luvdisk Unknown (Unown) Vanilluxe
# 790  I don’t pretend to be an ordinary housewife Pe...
# 797  Rachel Crawley High fat vegan plant based diet...
#
#                                            gen_spoiler
# 1    "intentionally" could transform a court case a...
# 3                     Alan Rickman & Rupert Grint CBGB
# 10   , so weights, and quite a few planks for my co...
# 13   Marcia Clark Does she think Simpson really did...
# 14              Mitzi Gaynor Beverly Hills, California
# ..                                                 ...
# 785  – Portugal Meadows in the Mountains – Bulgaria...
# 788  Elizabeth is outgoing, vivacious, and comes of...
# 789      Klefki Rotom Luvdisk Unknown (Unown) Vanillux
# 790  I don’t pretend to be an ordinary housewife Pe...
# 797  Rachel Crawley High fat vegan plant-based diet...
#
# [143 rows x 3 columns]

# %%
bleu_scores = []
for i in range(len(dataframe)):
# for data_results in dataframe[0]:
  score_ref = bleu.sentence_bleu([dataframe.iloc[i]["gen_spoiler"]], dataframe.iloc[i]["actual_spoiler"])
  bleu_scores.append(score_ref)

# %%
bleu_scores
# Out:
# [0.6391801085391197,
#  1.0,
#  0.2961214417513839,
#  1.0,
#  1.0,
#  0.24229344727106872,
#  0.27867544187454296,
#  0.1423317757524825,
#  0.23692798975551865,
#  1.0,
#  0.6642444377110098,
#  8.433443371185627e-232,
#  0.920043984132092,
#  0.49813191889374797,
#  0.09820611087532359,
#  0.9039676305405135,
#  0.0957804885220674,
#  0.5696740611412793,
#  0.9432751499445083,
#  0.2469911553886313,
#  0.07422748610849904,
#  0.08263132623634878,
#  0.7235536312142931,
#  1.0,
#  1.0,
#  0.9510699415570292,
#  0.2011156792819788,
#  0.16319551222068077,
#  0.3497296423600651,
#  8.791073860502197e-232,
#  0.8778245140618518,
#  0.24003990789584254,
#  1.0,
#  0.3823042728920807,
#  0.3661399117369223,
#  0.5229375060341007,
#  0.5100563379411251,
#  1.1029358421665475e-231,
#  0.41861541968268573,
#  0.35382008561635336,
#  1.0,
#  0.3933806455800525,
#  0.9789355686151718,
#  0.2387036916734352,
#  0.14960432113145486,
#  0.2810905968989457,
#  0.6776803078053107,
#  0.5864480937129979,
#  0.15404035990073003,
#  0.5642206614759113,
#  0.3633094968123723,
#  0.23737937676867238,
#  0.3732447099302188,
#  0.4467357174225074,
#  0.7165535536923066,
#  0.24886834992941437,
#  0.13120638292370448,
#  0.5762026580484605,
#  1.0,
#  0.5021486707109675,
#  0.11590134736933043,
#  0.5569610934716941,
#  0.9151329413834155,
#  0.5467202253148133,
#  0.7606443295269258,
#  0.3629076282680082,
#  0.5226289574868027,
#  0.15407350225163488,
#  1.0,
#  0.6807436745443053,
#  0.18997220559700884,
#  1.0,
#  0.49772923457352053,
#  0.028927377532711945,
#  0.21376196604086878,
#  0.28815546668307396,
#  0.2636289309894783,
#  0.27400048050370057,
#  0.5058257887397873,
#  0.7136539434951662,
#  1.0,
#  0.11905047845068276,
#  0.549241027849353,
#  0.1705875654844083,
#  0.3545369644696898,
#  0.8283550361833236,
#  0.6377027242709312,
#  0.45856142951404366,
#  1.0,
#  0.30056018543412333,
#  0.5733939764079907,
#  0.07527147180538625,
#  1.0,
#  0.36203098807477546,
#  0.6998528512951685,
#  0.6703200460356393,
#  0.23935848531309695,
#  0.2489010084557865,
#  0.5362039738843265,
#  6.150149066359227e-232,
#  0.2231809816904478,
#  0.1440067770191148,
#  0.733952013621656,
#  0.8902056737869248,
#  0.31889605568129736,
#  0.11198152817660835,
#  0.4868471631040818,
#  0.4456298130995599,
#  0.8128298033324055,
#  0.9740274534203012,
#  0.27041870044843364,
#  0.1323780072379578,
#  0.7200744992561828,
#  0.17690956853307668,
#  0.5852511043074122,
#  0.34136642464501693,
#  0.2210283035977995,
#  0.37825041055641406,
#  0.5391955298456643,
#  0.10535571013836773,
#  0.762170526105031,
#  0.058931336145665925,
#  0.8456264939786192,
#  1.0,
#  0.40249985154892826,
#  0.7894935331710389,
#  0.1433506469344118,
#  0.5522553193135571,
#  0.6685812142077141,
#  1.0,
#  0.5913517690802388,
#  0.748244564086645,
#  0.12349945654493807,
#  0.7196772759280428,
#  0.7928328533799701,
#  0.9635749534339606,
#  0.5660870580784694,
#  0.16080953630366684,
#  0.5293710644694106,
#  0.16083573379181385,
#  0.9775137267097118,
#  0.30364708495171105,
#  0.8887010410724315]

# %%
bleu_average = round(sum(bleu_scores) / len(bleu_scores), 2)
bleu_average
# Out:
# 0.5

# %%
bleu_min = min(bleu_scores)
bleu_min
# Out:
# 6.150149066359227e-232

# %%
bleu_max = max(bleu_scores)
bleu_max
# Out:
# 1.0

# %%
bleu_scores.sort()
mid = len(bleu_scores) // 2
res = (bleu_scores[mid] + bleu_scores[~mid]) / 2
bleu_median = res
bleu_median
# Out:
# 0.49772923457352053

# %%
import sys
from nltk.translate.meteor_score import meteor_score

# %%
meteor_scores = []
for i in range(len(dataframe)):
# for data_results in dataframe[0]:
  gen_spoiler_strip = dataframe.iloc[i]["gen_spoiler"].strip()

  ref = word_tokenize(gen_spoiler_strip)
  hypo = word_tokenize(dataframe.iloc[i]["actual_spoiler"].strip())
  meteor = nltk.translate.meteor_score.meteor_score([ref], hypo)


  # meteor = nltk.translate.meteor_score.meteor_score([gen_spoiler_strip], dataframe.iloc[i]["actual_spoiler"].strip())
  # meteor = round(meteor_score([dataframe.iloc[i]["gen_spoiler"]], dataframe.iloc[i]["actual_spoiler"]), 2) # list of references
  meteor_scores.append(meteor)

# %%
meteor_scores
# Out:
# [0.8690693430656935,
#  0.9976851851851852,
#  0.8250907725053211,
#  0.9995,
#  0.9976851851851852,
#  0.5324074074074074,
#  0.7087053571428573,
#  0.46368133650519033,
#  0.703125,
#  0.9976851851851852,
#  0.4406130268199233,
#  0.0,
#  0.8211575489862951,
#  0.7987625996690236,
#  0.5271084337349399,
#  0.9004504504504506,
#  0.43176454255171465,
#  0.9492264416315049,
#  0.9914203039316862,
#  0.7502790178571429,
#  0.37390827019026246,
#  0.3573459116848112,
#  0.7063829787234043,
#  0.9990234375,
#  0.9985422740524781,
#  0.9814814814814815,
#  0.10309278350515463,
#  0.4650000000000001,
#  0.7904761904761907,
#  0.0,
#  0.8737244897959183,
#  0.7996000000000001,
#  0.9998779296875,
#  0.44834307992202727,
#  0.6640712682379349,
#  0.7003676470588235,
#  0.9107433164739884,
#  0.0,
#  0.6729787431541817,
#  0.8391868512110727,
#  0.9976851851851852,
#  0.6938775510204082,
#  0.9985422740524781,
#  0.7582012736966826,
#  0.46273825430152976,
#  0.6523622047244095,
#  0.8748326350796872,
#  0.9350389510876507,
#  0.46150216565441476,
#  0.7178178963893249,
#  0.78334686931972,
#  0.5808080808080809,
#  0.8200152207001523,
#  0.3073770491803279,
#  0.592435298141603,
#  0.18564356435643567,
#  0.42487179487179494,
#  0.4429133858267717,
#  0.9997724169321802,
#  0.7954545454545456,
#  0.48478260869565226,
#  0.26483781918564525,
#  0.9993141289437586,
#  0.745792668869592,
#  0.7812499999999999,
#  0.2717391304347826,
#  0.8780549256739735,
#  0.5202797202797204,
#  0.996,
#  0.6384477459016394,
#  0.6044703595724005,
#  0.9993141289437586,
#  0.7263761879146495,
#  0.0,
#  0.2587090163934426,
#  0.8072916666666666,
#  0.6089882761615284,
#  0.7407407407407407,
#  0.895757270552688,
#  0.8887898192429278,
#  0.9995,
#  0.0,
#  0.8064208518753974,
#  0.4361111111111111,
#  0.7885514018691588,
#  0.7782659533004996,
#  0.8964937057572272,
#  0.6405844155844156,
#  0.9976851851851852,
#  0.7710137249383289,
#  0.855692729766804,
#  0.4471237024221454,
#  0.9998518518518519,
#  0.8473320778405524,
#  0.8295072115384616,
#  0.6552706552706553,
#  0.7417293233082707,
#  0.3532846715328467,
#  0.7378371836591991,
#  0.22727272727272732,
#  0.49951171875,
#  0.5852417302798981,
#  0.9754906631097561,
#  0.9995,
#  0.8439383301152654,
#  0.4407408329391851,
#  0.7654808246828143,
#  0.7646914187361692,
#  0.9753274616079494,
#  0.8979985955056179,
#  0.756670881022092,
#  0.4176469472166357,
#  0.9625687247774793,
#  0.5055994729907775,
#  0.754985754985755,
#  0.8179790279802575,
#  0.5737140352524968,
#  0.8229929351316634,
#  0.9319727891156462,
#  0.3703703703703703,
#  0.9629141566265061,
#  0.3473973072635281,
#  0.9279820525495265,
#  0.9976851851851852,
#  0.644161556918155,
#  0.8394224733207784,
#  0.5660377358490567,
#  0.32877604166666663,
#  0.7469334112149533,
#  0.996,
#  0.7495798319327731,
#  0.9191547375596457,
#  0.4836775347589235,
#  0.9703883495145632,
#  0.741822429906542,
#  0.996,
#  0.8714728494948276,
#  0.5506172839506174,
#  0.9225908906609,
#  0.6484609609609611,
#  0.9990234375,
#  0.724817620650954,
#  0.8444148936170212]

# %%
meteor_scores_average = round(sum(meteor_scores) / len(meteor_scores), 2)
meteor_scores_average
# Out:
# 0.7

# %%
meteor_scores_max = max(meteor_scores)
meteor_scores_max
# Out:
# 0.9998779296875

# %%
meteor_scores_min = min(meteor_scores)
meteor_scores_min
# Out:
# 0.0

# %%
meteor_scores.sort()
mid = len(meteor_scores) // 2
res = (meteor_scores[mid] + meteor_scores[~mid]) / 2
meteor_scores_median = res
meteor_scores_median
# Out:
# 0.756670881022092

# %%
# !pip install bert-score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.0.0+cu118)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.5.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.29.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.27.1)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert-score) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert-score) (16.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.14.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers>=3.0.0->bert-score) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.1->bert-score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13

# %%
from bert_score import score

# %%
# !git clone https://github.com/Tiiiger/bert_score.git
# Out:
# Cloning into 'bert_score'...
# remote: Enumerating objects: 993, done.
# remote: Counting objects: 100% (355/355), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 993 (delta 219), reused 322 (delta 198), pack-reused 638
# Receiving objects: 100% (993/993), 1.34 MiB | 10.33 MiB/s, done.
# Resolving deltas: 100% (534/534), done.

# %%
bert_scores_P = []
bert_scores_R = []
bert_scores_F1 = []
for i in range(len(dataframe)):
# for data_results in dataframe[0]:
  gen_spoiler_strip = dataframe.iloc[i]["gen_spoiler"]
  actual_spoiler_strip = dataframe.iloc[i]["actual_spoiler"]


  ref = word_tokenize(gen_spoiler_strip)
  hypo = word_tokenize(actual_spoiler_strip)

  P, R, F1 = score(gen_spoiler_strip, actual_spoiler_strip, lang="en", verbose=True)
  bert_scores_P.append(P)
  bert_scores_R.append(R)
  bert_scores_F1.append(F1)

  # meteor = nltk.translate.meteor_score.meteor_score([gen_spoiler_strip], dataframe.iloc[i]["actual_spoiler"].strip())
  # meteor = round(meteor_score([dataframe.iloc[i]["gen_spoiler"]], dataframe.iloc[i]["actual_spoiler"]), 2) # list of references
  # meteor_scores.append(meteor)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 4>:13                                                                             │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/bert_score/score.py:70 in score                          │
# │                                                                                                  │
# │    67 │   │   │   │     multiple references, the returned score of this candidate is             │
# │    68 │   │   │   │     the *best* score among all references.                                   │
# │    69 │   """                                                                                    │
# │ ❱  70 │   assert len(cands) == len(refs), "Different number of candidates and references"        │
# │    71 │                                                                                          │
# │    72 │   assert (                                                                               │
# │    73 │   │   lang is not None or model_type is not None                                         │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AssertionError: Different number of candidates and references

# %%
# P, R, F1 = score(cands, refs, lang="en", verbose=True)

# %%
for i in range(len(dataframe)):
# for data_results in dataframe[0]:
  gen_spoiler_strip = dataframe.iloc[i]["gen_spoiler"]
  actual_spoiler_strip = dataframe.iloc[i]["actual_spoiler"]


  ref = word_tokenize(gen_spoiler_strip)
  hypo = word_tokenize(actual_spoiler_strip)

  print("\n")
  print(ref)
  print("\n")
  print(hypo)
  print("\n")
# Out:
# ['tom', 'brady', "'", 's', 'definition', 'of', 'catching', 'up', 'involves', 'much', 'more', 'than', 'just', 'a', 'meal', '.', 'wes', 'welker', 'contacted', 'the', 'patriots', 'quarterback', 'friday', 'morning', 'on', 'a', 'miami', 'radio', 'station', '.', 'bra']
#
#
# ['how', 'about', 'that', 'morning', 'we', 'go', 'throw', '?']
#
#
#
#
# ['nasa', 'scientists', 'are', 'predicting', 'the', 'hole', 'in', 'the']
#
#
# ['2070']
#
#
#
#
# ['research', 'by', 'hiring', 'software', 'provider', 'cangrade', 'found', 'that', 'being', 'intellectually', 'stimulated']
#
#
# ['intellectual', 'stimulation']
#
#
#
#
# ['cal', 'newport', "'", 's', 'investigation', 'into', 'how', 'passionate', 'people', 'like', 'steve', 'jobs', 'really', 'got', 'started', 'as', 'well', 'as', 'what', 'scientists', 'say', 'predicts', 'happiness', 'and', 'fuels', 'great', 'accomplishment', 'newport', '.', 'ryan', 'holiday', 'author', 'of', 'ego', 'is', 'the', 'enemy', 'your', 'passion', 'may', 'be', 'the', 'very', 'enemy', '.', 'the', 'only', 'way', 'to', 'do', 'great', 'work', 'is', 'to', 'love', 'what', 'you', 'do', 'if', 'you', 'have', "n't", 'found', 'it', 'yet', 'keep', 'looking', 'dont', 'settle', 'in', 'other', 'words', 'follow', 'your', 'passion', 'there', '.']
#
#
# ['Purpose', 'connects', 'us', 'to', 'something', 'bigger', 'and', 'in', 'doing', 'so', 'makes', 'us', 'right', 'sized', 'be', 'ruthless', 'with', 'your', '``', 'No', '’', 's', '.', "''", 'Practice', 'means', 'greatness', 'is', 'doable', '...', 'one', 'tiny', 'step', 'after', 'another', 'planning', 'of', 'the', 'SMART', 'goal', 'and', 'number-crunching', 'variety', 'Objectivity', '—', 'the', 'ability', 'to', 'see', 'the', 'world', 'as', 'it', 'truly', 'is']
#
#
#
#
# ['the', 'top', 'voted', 'answer', 'for', 'how', 'to', 'cook', 'rice', 'has', 'been', 'shared', 'on']
#
#
# ['in', 'a', 'rice', 'cooker']
#
#
#
#
# ['apple', 'iphone', 'event', 'introduced', 'airpods', 'apples', 'totally', 'wireless', 'headphones', '.', 'one', 'of', 'the', 'biggest', 'surprise', 'announcements', 'was', 'about', 'theft', '.', 'no', 'apple', 'says', 'that', 'if', 'one', 'of', 'your', 'airpod', '.', 'is', 'lost', 'or', 'stolen', 'youll', 'have', 'to', 'buy', 'new', 'ones']
#
#
# ['Apple', 'says', 'that', 'if', 'AirPods', 'are', 'lost', 'or', 'stolen', ',', 'you', "'ll", 'have', 'to', 'buy', 'new', 'ones', ',', 'just', 'like', 'any', 'other', 'Apple', 'product', '.']
#
#
#
#
# ['june', '14th', '2016', '33k', 'shares', 'they', 'may', 'look', 'like', 'the', 'sort', 'of', 'apparel', 'youd', 'normally', 'sport', 'on', 'the', 'morning', 'after', '12', 'pints', 'so', 'the', 'elasticated', 'waist', 'can', 'provide', 'enough', 'give', 'to', 'support', 'two', 'hangover', 'curing', 'trips', 'to', 'macc']
#
#
# ['``', 'The', 'more', 'good', 'games', 'I', 'had', 'in', 'them', ',', 'the', 'more', 'I', 'got', 'used', 'to', 'them', '.']
#
#
#
#
# ['it', 'was', 'cold', 'and', 'very', 'foggy', 'the', 'temperature', 'was', 'around', '10', 'degrees', 'celsius', 'said', 'hänninen', 'when', 'the', 'clouds', 'began', 'to', 'break', 'there', 'were', 'rainbow', 'colours', 'in', 'the', 'sky', 'and', 'a', 'halo', 'spanning', '360', 'degrees', '.']
#
#
# ['rainbow', 'colours', 'in', 'the', 'sky', 'and', 'a', 'halo', 'spanning', '360', 'degrees']
#
#
#
#
# ['julia', 'zumpano', 'a', 'dietitian', 'at', 'cleveland', 'clinic', "'", 's', 'heart', 'vascular', 'institute', 'says', 'red', 'wine', 'has', 'a', 'purplestained', 'smile', 'at', '125', 'calories', 'for', 'a', 'fiveounce', 'pour', '.']
#
#
# ['Red', 'wine', 'is', 'clearly', 'the', 'drink', 'of', 'choice', 'if', 'you', 'are', 'doing', 'light', 'to', 'moderate', 'drinking', 'for', 'your', 'health', ',', 'and', 'daily', 'consumption', 'just', 'before', 'or', 'with', 'the', 'evening', 'meal', 'may', 'be', 'the', 'most', 'protective', 'pattern', ',', "''", 'O', '’', 'Keefe', 'says']
#
#
#
#
# ['we', 'tried', '29', 'different', 'kinds', 'of', 'hot', 'sauce', 'to', 'find', 'our', 'favorite', 'what', 'the', 'hell', 'were', 'we', 'thinking', 'weve', 'put', 'ourselves', 'through', 'a', 'fair', 'number', 'of', 'taste', 'tests', 'to', 'find', 'you', 'the', 'best', 'of', 'the', 'best', 'there', 'was', 'that', 'time', 'we', 'filled', 'a', 'room', 'with', '264', 'donuts', 'to', 'narrow', 'down', 'the', 'best', '.', 'we', 'wanted', 'to', 'find', 'the', 'best', 'macarons', 'oh', 'and', 'thanksgiving', 'pie', 'after', 'all', 'that', 'sugar', 'we', 'needed', 'to', 'take', 'a', 'step', 'away', 'from', 'the', 'sweet', 'side', 'in', 'our', 'beloved', 'town', '.']
#
#
# ['Sriracha', 'Hot', 'Chili', 'Sauce', 'Frank', "'s", 'RedHot', 'Original', 'Sauce', 'Cholula', 'Chili', 'Garlic', 'Louisiana', 'Hot', 'Sauce', 'CaJohns', 'Bourbon', 'Infused', 'Chipotle-Habañero', 'Sauce']
#
#
#
#
# ['cbo', '64-year-olds', 'making', '26500', 'per']
#
#
# ['750', 'percent']
#
#
#
#
# ['jenelle', 'evans', 'and', 'boyfriend', 'nathan']
#
#
# ['boy']
#
#
#
#
# ['more', 'than', 'a', 'quarter', 'of', 'shoppers', 'use', 'it', 'we', 'asked', 'the', 'experts', 'for']
#
#
# ['promotional', 'code']
#
#
#
#
# ['target', 'will', 'spend', '20', 'million', 'to', 'expand', 'its', 'use', 'of', 'a', 'third', 'singletoilet', 'bathroom', 'at', 'all', 'of', 'its', 'stores', 'target', 'tgt', 'cfo', 'cathy', 'smith', 'said', 'wednesday', 'that', 'the', 'company', 'has', 'heard', 'objections']
#
#
# ['says', 'it', 'will', 'spend', '$', '20', 'million', 'to', 'expand', 'bathroom', 'options', 'at', 'all', 'of', 'its', 'U.S.', 'stores']
#
#
#
#
# ['the', 'newest', 'fad', 'in', 'china', 'is', 'glass', 'pedestrian', 'bridges', 'the', 'chinese', 'people', 'love', 'nothing', 'more', 'than', 'walking', 'over', 'great', 'heights', 'while', 'imagining', 'their', 'own', 'deaths', 'apparently', 'or', 'maybe', 'they', 'just', 'like', 'laughing', 'at', 'the', 'people', 'who', 'cant']
#
#
# ['Although', 'Simmons', "'", 'first', 'blow', 'shattered', 'the', 'glass', ',', 'he', 'was', 'unable', 'to', 'structurally', 'compromise', 'the', 'underlying', 'layers', 'even', 'after', 'he', 'let', 'loose', 'on', 'it', 'dozens', 'of', 'times', '.']
#
#
#
#
# ['mashable', 'instagram', 'is', 'killing', 'feature', 'that', 'allowed', 'you', 'to', 'see', 'a', 'map', 'of', 'where', 'a', 'given', 'user', 'photos', 'were', 'taken', 'if', 'they', 'designated', 'a', 'location', 'for', 'the', 'photo', 'you', 'could', 'zoom', 'in', 'on', 'maps', 'to', 'get', 'a', 'closer', 'view']
#
#
# ['the', 'feature', 'that', 'allowed', 'you', 'to', 'see', 'a', 'map', 'of', 'where', 'a', 'given', 'user', "'s", 'photos', 'were', 'taken', '(', 'if', 'they', 'designated', 'a', 'location', 'for', 'the', 'photo', ')', '.']
#
#
#
#
# ['researchers', 'from', 'the', 'harvard', 'th', 'chan', 'school', 'of', 'public', 'health', 'took', 'a', 'bunch', 'of', 'trips', 'on', 'the', 'boston', 'city', 'subway', 'and', 'started', 'swabbing', 'in', 'their', 'new', 'study', 'published', 'in', 'the', 'american', 'society', 'for', 'microbiology', '.']
#
#
# ['scientists', 'didn', '’', 't', 'find', 'pathogenic', 'organisms', 'that', 'typically', 'cause', 'sickness', 'or', 'antibiotic-resistant', 'genes']
#
#
#
#
# ['hogwarts', 'jk', 'rowlings', 'response', 'in', '2000', 'gave', 'the', 'answer', 'about', '1000', 'but', 'when', 'you', 'look', 'closer', 'that', 'number', 'doesnt', 'make', 'a', 'lot', 'of', 'sense', 'why', 'are', 'there', 'so', 'few', 'students', 'in', 'harrys', 'year', 'this', 'screencap']
#
#
# ['because', 'of', 'the', 'war', 'with', 'Voldemort', '.']
#
#
#
#
# ['vw', 'beetle', 'dune', 'is', 'a', 'special', 'edition', 'of', 'the', 'iconic', 'reboot', 'of', 'the', 'legendary', 'peoples', 'car', '.', 'it', 'has', 'an', 'amazing', 'audio', 'system', 'and', 'is', 'pretty', 'cheap', 'at', 'less', 'than', '25000', 'but', 'it', 'also', 'has', 'a']
#
#
# ['just', 'that', 'famous', 'VW', 'badge', '...', '...', 'which', 'flips', 'open', 'when', 'the', 'car', 'is', 'in', 'reverse', 'to', 'reveal', 'the', 'hidden', 'camera', '!']
#
#
#
#
# ['macarena', 'is', 'a', 'siren', 'enticing', 'young', 'men', 'to', 'come', 'and', 'dance', 'with', 'her', 'if', 'they', 'can', 'curry', 'her', 'favor', 'she', 'may', 'even', 'take', 'them', 'home', 'with', 'her', 'so', 'far', 'nothing', 'too', 'unusual', 'right', 'just', 'a', 'woman', 'out', 'on', 'the', 'town']
#
#
# ['``', 'Macarena', "''", 'is', 'about', 'a', 'woman', 'who', 'waits', 'until', 'her', 'boyfriend', 'leaves', 'town', 'and', 'then', 'bangs', 'his', 'two', 'best', 'friends', 'at', 'the', 'same', 'time', '.']
#
#
#
#
# ['the', 'remains', 'were', 'found', 'near', 'a', 'shed', 'in', 'the', 'backyard', 'of', 'a', 'home', 'in', 'southampton', 'county', 'early', 'thursday', '.', 'authorities', 'visited', 'the', 'home', 'on', 'a', 'tip', 'as', 'part', 'of', 'their', 'investigation', 'but', 'did', 'not', 'say', 'they', 'were', 'definitely', 'those', 'of', '18-year-old', 'anjelica', 'aj', 'hadsell', '.', 'the', 'office', 'of', 'the', 'chief', 'medical', 'examiner', 'will', 'run', 'tests', 'to', 'identify', 'the', 'remains', 'the', 'college', 'student', 'was', 'home', 'for', 'spring', 'break', '.']
#
#
# ['Southampton', 'County', 'Anjelica', "'AJ", "'", 'Hadsell']
#
#
#
#
# ['goopcom', 'is', 'a', 'ritzy', 'lifestyle', 'publication', 'or', 'a', 'grab', 'bag', 'of', 'the', 'ridiculous', 'from', 'advice', 'on', 'vaginal', 'steam', 'treatments', 'to', 'a', 'shopping', 'section', 'featuring', '73', 'wooden', 'spoon', 'and', 'a', '576', 'earring', '.']
#
#
# ['contain', 'the', 'element', 'in', 'various', 'compounds', ',', 'and', 'peddling', 'the', 'item', 'on', 'the', 'same', 'website', 'that', 'calls', 'it', 'dangerous']
#
#
#
#
# ['an', 'afghan', 'migrant', 'attacked', 'a', 'woman', 'at', 'an', 'asylum', 'centre', 'in', 'austria', 'because', 'she', 'was', 'reading', 'a', 'bible', '.', 'the', 'attack', 'took', 'place', 'in', 'the', 'town', 'of', 'timelkam', 'in', 'the', 'state', 'of', 'upper', 'austria', '.']
#
#
# ['An', 'Afghan', 'migrant', 'attacked', 'a', 'woman', 'at', 'an', 'asylum', 'centre', 'in', 'Austria', 'because', 'she', 'was', 'reading', 'a', 'bible']
#
#
#
#
# ['walt', 'disney', 'studios', 'moved', 'pirates', 'of', 'the', 'caribbean', '5', 'from', 'july', '10', '2015', 'to', 'an', 'unspecified', 'date', 'in', '2016', '.', 'thr', 'had', 'more', 'on', 'the', 'move', 'script', 'issues', 'are', 'said', 'to', 'be', 'the', 'cause']
#
#
# ["'Pirates", '5', "'", 'Release', 'Date', 'Shifted', 'To', '2016']
#
#
#
#
# ['tom', 'hiddleston', 'is', 'setting', 'the', 'record', 'straight', 'about', 'dating', 'taylor', 'swift', 'the', 'thor', 'actor', 'tried', 'to', 'clear', 'this', 'whole', 'messy', 'situation', 'up', 'once', 'and', 'for', 'all', 'on', 'thursday', 'july', '14', '.', 'the', 'h']
#
#
# ['``', 'That', "'s", 'the', 'truth', '.', 'It', "'s", 'not', 'a', 'publicity', 'stunt', '.', "''"]
#
#
#
#
# ['dis', '177', 'an', 'alligator', 'killed', 'a', '2year-old']
#
#
# ['Bees', ',', 'wasps', 'and', 'hornets']
#
#
#
#
# ['brenham', 'police', 'department', 'created', 'a', 'facebook', 'post', 'that', 'read', 'in', 'part', 'we', 'know', 'this', 'was', 'an', 'isolated', 'incident', 'that', 'involved', 'a', 'single', 'employee', 'who', 'is', 'not', 'fond', 'of', 'law', 'enforcement', 'the', 'offduty', 'officer', 'ended', 'up', 'eating', 'at', 'the', 'chain', 'after', 'another', 'employee', 'stepped']
#
#
# ['The', 'off-duty', 'officer', 'ended', 'up', 'eating', 'at', 'the', 'chain', ',', 'after', 'another', 'employee', 'stepped', 'in', '.', 'The', 'employee', 'who', 'refused', 'to', 'serve', 'him', 'was', 'fired', 'immediately', 'after', 'the', 'incident', '.']
#
#
#
#
# ['snapchat', 'will', 'now', 'run', 'video', 'ads', 'in', 'between', 'your', 'friends', "'", 'stories', 'to', 'give', 'advertisers', 'a', 'better', 'shot', 'at', 'reaching', 'some', 'of', 'the', 'company', "'", 's', '150', 'million', 'daily', 'users', 'the', 'video', 'ads', 'will', 'be', 'known', 'by', 'the', 'extremely', 'clever', 'name', 'snap', 'ads', 'between']
#
#
# ['video', 'ads', 'in', 'between', 'your', 'friends', '’', 'stories']
#
#
#
#
# ['mhairi', 'black', 'was', '20', 'when', 'she', 'won', 'the', 'seat', 'of', 'paisley', 'and', 'renfrewshire', 'south', 'for', 'the', 'snp', 'from', 'labour', 's', 'douglas', 'alexander', 'in', '2015', '.', 'the', 'youngest', 'mp', 'elected']
#
#
# ['Black', ',', 'who', 'was', '20', 'when', 'she', 'won', 'the', 'seat', 'of', 'Paisley', 'and', 'Renfrewshire', 'South', 'for', 'the', 'SNP']
#
#
#
#
# ['the', 's', 'has', 'appeared', 'throughout', 'all', 'of', 'north', 'america', 'south', 'america', 'europe', 'russia', 'asia', 'and', 'australia', 'some', 'people', 'think', 'its', 'a', '90s', 'thing', 'others', 'report', 'seeing', 'it', 'as', 'early', 'as', 'the', '1960s', 'there', 'were', 'theories', 'that', 'it', 'was', 'the', 'symbol']
#
#
# ['it', "'s", 'just', 'the', 'most', 'fun', 'ever']
#
#
#
#
# ['cyprus', 'is', 'the', 'cheapest', 'option', 'for', 'a', 'last']
#
#
# ['Cyprus']
#
#
#
#
# ['google', 'paid', 'a', 'tax', 'rate', 'of', '26', 'percent', 'on', '81', 'billion', 'in']
#
#
# ['UK', 'tax', 'bill', 'of', '35', 'million', 'pounds', '(', '$', '55', 'million', ')', 'in', '2012']
#
#
#
#
# ['paul', 'servat', 'was', 'waiting', 'to', 'see', 'his', 'first', 'baby', 'but', 'five']
#
#
# ['was', 'not', 'pregnant']
#
#
#
#
# ['most', 'successful', 'businesses', 'operate', 'by', 'following', 'a', 'fundamental', 'set', 'of', 'core', 'values', 'their']
#
#
# ['own', 'personal', 'values']
#
#
#
#
# ['the', 'drug', 'enforcement', 'administration', 'says', 'marijuana', 'lacks', 'medical', 'value', 'so', 'why', 'did', 'the', 'us', 'government', 'file', 'a', 'patent', 'for', 'cannabis', 'as', 'far', 'back', 'as', '1999', '.', 'the', 'dea', 'declined', 'to', 'loosen', 'federal', 'restrictions', 'on', 'cannabis', 'last', 'week', 'to', 'highlight', 'the', 'seeming', 'contradiction', 'they']
#
#
# ['one', 'patent', ',', 'number', '6630507', ',', 'disqualifies', 'cannabis', 'from', 'the', 'Controlled', 'Substances', 'Act']
#
#
#
#
# ['the', 'trailer', 'for', 'what', 'if', 'with', 'daniel', 'rad']
#
#
# ['``', 'Obvious', 'Child', "''"]
#
#
#
#
# ['kate', 'middleton', 'and', 'prince', 'william', 'are', 'looking', 'for']
#
#
# ['housekeeper']
#
#
#
#
# ['student', 'debt', 'derails', 'young', 'people', 'from', 'the', 'american', 'dream', 'of', 'owning', 'a', 'home', 'that', 'depends', 'on', 'which', 'headline', 'you', 'click', 'so', 'what', "'", 's', 'really', 'going', 'on', 'here', 'the', 'findings', 'of', 'the', 'two', 'studies', 'don', '’', 't', 'exactly', 'contradict', '.']
#
#
# ['student', 'debt', 'does', 'delay', 'major', 'life', 'decisions', 'like', 'homeownership']
#
#
#
#
# ['hillary', 'clinton', 'has', 'been', 'asked', 'this', 'question', 'repeatedly', 'during', 'her', 'campaign']
#
#
# ['the', 'first', 'gentleman']
#
#
#
#
# ['national', 'motorists', 'association', 'has', 'declared', 'june', 'lane', 'courtesy', 'month', 'in', 'an', 'effort', 'to', 'raise', 'the', 'risk', 'of', 'accidents', '.', 'the', 'system', 'works', 'best', 'when', 'people', 'arent', 'hogging', 'the', 'left', 'lane', 'thats', 'one', 'reason', 'why', 'the', 'national', 'motorist']
#
#
# ['it', "'ll", 'inevitably', 'lead', 'to', 'buildups', 'of', 'traffic', 'and', 'likely', 'raise', 'the', 'chance', 'of', 'accidents']

# %%
bert_scores_P

# %%
bert_scores_R

# %%
bert_scores_F1
